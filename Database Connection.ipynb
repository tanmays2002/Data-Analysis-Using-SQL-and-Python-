# %%
# !pip install mysql
# Out:
# ...
#   Using cached mysql-0.0.3-py3-none-any.whl (1.2 kB)
# ...

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
from mysql.connector import Error

# %%
# Making connection

try:
    connection = mysql.connector.connect(host = 'localhost',
                                         database = 'sakila',
                                         user = 'root',
                                         password = 'Tanmay@2002')
    if connection.is_connected():
            db_info = connection.get_server_info()
            print('Connection to MySQL Server version',db_info)
            cursor = connection.cursor()
            cursor.execute('select database();')
            record = cursor.fetchall()
            print('You are connected to database:',record)

            
except Error as e:
    print('Error while connecting to MySQL',e)
    
finally:
    if connection.is_connected():
        cursor.close()
        connection.close()
        print('MySQL connection is close')
# Out:
# Connection to MySQL Server version 8.0.26
# You are connected to database: [('sakila',)]
# MySQL connection is close

# %%
#Step1- Import mysql.connector and Error
import mysql.connector
from mysql.connector import Error

# %%
# making a connection to MySQL
try:
    connection = mysql.connector.connect(host='localhost',
                                          password = 'Tanmay@2002',f
                                          user = 'root',
                                          database = 'world')
    
    # Checking the connection 
    if connection.is_connected():
        db_info = connection.get_server_info()
        print('Connection to MySQL server version',db_info)
        
        
except Error as e:
    print('Error while connecting to MySQL',e)
# Out:
# Connection to MySQL server version 8.0.26

# %%
#Creating Cursor Object.
cursor = connection.cursor()

# %%
# Run Quaries
cursor.execute('select * from city;')

# Result
result = cursor.fetchall()
result
# Out:
# [(1, 'Kabul', 'AFG', 'Kabol', 1780000),
#  (2, 'Qandahar', 'AFG', 'Qandahar', 237500),
#  (3, 'Herat', 'AFG', 'Herat', 186800),
#  (4, 'Mazar-e-Sharif', 'AFG', 'Balkh', 127800),
#  (5, 'Amsterdam', 'NLD', 'Noord-Holland', 731200),
#  (6, 'Rotterdam', 'NLD', 'Zuid-Holland', 593321),
#  (7, 'Haag', 'NLD', 'Zuid-Holland', 440900),
#  (8, 'Utrecht', 'NLD', 'Utrecht', 234323),
#  (9, 'Eindhoven', 'NLD', 'Noord-Brabant', 201843),
#  (10, 'Tilburg', 'NLD', 'Noord-Brabant', 193238),
#  (11, 'Groningen', 'NLD', 'Groningen', 172701),
#  (12, 'Breda', 'NLD', 'Noord-Brabant', 160398),
#  (13, 'Apeldoorn', 'NLD', 'Gelderland', 153491),
#  (14, 'Nijmegen', 'NLD', 'Gelderland', 152463),
#  (15, 'Enschede', 'NLD', 'Overijssel', 149544),
#  (16, 'Haarlem', 'NLD', 'Noord-Holland', 148772),
#  (17, 'Almere', 'NLD', 'Flevoland', 142465),
#  (18, 'Arnhem', 'NLD', 'Gelderland', 138020),
#  (19, 'Zaanstad', 'NLD', 'Noord-Holland', 135621),
#  (20, 'Â´s-Hertogenbosch', 'NLD', 'Noord-Brabant', 129170),
# ...

# %%
# Run Quaries
cursor.execute('select count(*) from city;')

#Result
result = cursor.fetchall()
result
# Out:
# [(4079,)]

# %%
# Close the connection
cursor.close()
# Out:
# True

# %%
# Importing MySQL connection and Error
import mysql.connector
from mysql.connector import Error

# %%
# Making connection to the Database
connection = mysql.connector.connect(user = 'root',
                                    password = 'Tanmay@2002',
                                    host = 'localhost',
                                    database = 'world')

# Try and Except
try:
    if connection.is_connected():
        db_info = connection.get_server_info()
        print('Connected to the Database server',db_info)
except Error as e:
    print('Some error occured while connecting to the server',e)
# Out:
# Connected to the Database server 8.0.26

# %%
# Creating Cursor Object
cursor = connection.cursor()

# %%
# Run Quaries and Print the Result
cursor.execute("create table book (isbn int primary key, title varchar(20), edition varchar(10), year int)")
result = cursor.fetchall()
result
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     512                 query = query.encode('utf-8')
# --> 513             self._cmysql.query(query,
#     514                                raw=raw, buffered=buffered,
#
# MySQLInterfaceError: Table 'book' already exists
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-50-37ce3c24420b> in <module>
#       1 # Run Quaries and Print the Result
# ----> 2 cursor.execute("create table book (isbn int primary key, title varchar(20), edition varchar(10), year int)")
#       3 result = cursor.fetchall()
#       4 result
#
# ...
